# %% [markdown]
# # 目標:
#
#  安裝Basemap, 並且可以使用它繪製地理資訊. 這個教程中，我們將涉及地理繪圖module: Basemap。Basemap是Matplotlib的擴展.
#
# # 重點:
#  Basemap 在地圖集上的擴展應用
#
#
# # 作業:
#
#  1. 更改 Projection 的設定繪製出地球儀圖形
#
#  當 "projection" 參數為“ortho"時，所得圖位地球儀截面
#
#  當 "projection" 參數為“Mill"時，所得平展位面
#
#
#  2. 查看 resolution / 經緯度座標的繪圖精細度

# %%
# 載入套件
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# %%
# 創建基本地圖。
# 當 "projection" 參數為“ortho"時，所得圖位地球儀截面
'''
#由此開始寫code 

#設定圖形大小
plt.figure(...)

#設定投影型態
m=Basemap(....)

#設定圖形顏色, 選用NASA 寶石藍輸出 
m.bluemarble()

#秀圖
plt.show()
'''
#設定圖形大小
plt.figure(figsize=(4,4))

#設定投影型態
m=Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)

#設定圖形顏色, 選用NASA 寶石藍輸出 
m.bluemarble()

#秀圖
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
'''
由此開始寫code 

#設置Lambert保形底圖。
# width=12000000,height=9000000
#經緯度lat_1=45.,lat_2=55,lat_0=50,lon_0=-107
#set resolution = None跳過邊界數據集的處理
# projection='lcc'

m = Basemap(....)

#選用NASA 寶石藍輸出 
m.bluemarble()

#秀圖
plt.show()
'''

#設置Lambert保形底圖。
# width=12000000,height=9000000
#經緯度lat_1=45.,lat_2=55,lat_0=50,lon_0=-107
#set resolution = None跳過邊界數據集的處理
# projection='lcc'

m = Basemap(projection='lcc', width=12000000,height=9000000, resolution=None, lat_1=45.,lat_2=55,lat_0=50,lon_0=-107)

#選用NASA 寶石藍輸出 
m.bluemarble()

#秀圖
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
'''
由此開始寫code 
#  "projection" 參數為“Mill"
# 設定經緯座標
# 左下角的緯度 - llcrnrlat = -90,
# 左下角的經度 - llcrnrlon = -180,
# 右上角的緯度 - urcrnrlat = 90,
# 右上角的經度 -urcrnrlon = 180

# 成圖設定resolution

m = Basemap() # 成圖設定resolution 

#創建邊線
m.drawcoastlines()
#畫出國家，並使用線寬為2 的線條生成分界線。
m.drawcountries()
#畫出州界
m.drawstates(color='b')
#畫出城市
m.drawcounties(color='darkred')

plt.title('Basemap Tutorial')
plt.show()

'''

#  "projection" 參數為“Mill"
# 設定經緯座標
# 左下角的緯度 - llcrnrlat = -90,
# 左下角的經度 - llcrnrlon = -180,
# 右上角的緯度 - urcrnrlat = 90,
# 右上角的經度 -urcrnrlon = 180

# 成圖設定resolution

m = Basemap(projection='mill', llcrnrlat = -90, llcrnrlon = -180, urcrnrlat = 90, urcrnrlon = 180, resolution='c') # 成圖設定resolution 

#創建邊線
m.drawcoastlines()
#畫出國家，並使用線寬為2 的線條生成分界線。
m.drawcountries(linewidth = 2)
#畫出州界
m.drawstates(color='b')
#畫出城市
m.drawcounties(color='darked')

plt.title('Basemap Tutorial')
plt.show()
# Out:
# C:\Users\apply\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:37: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# C:\Users\apply\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:42: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# C:\Users\apply\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:44: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# C:\Users\apply\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:46: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-12-3cd086eff39e> in <module>
#      44 m.drawstates(color='b')
#      45 #畫出城市
# ---> 46 m.drawcounties(color='darked')
#      47
#      48 plt.title('Basemap Tutorial')
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\mpl_toolkits\basemap\__init__.py in drawcounties(self, linewidth, linestyle, color, antialiased, facecolor, ax, zorder, drawbounds)
#    1987         ax = ax or self._check_ax()
#    1988         county_info = self.readshapefile(gis_file,'counties',\
# -> 1989                       default_encoding='latin-1',drawbounds=drawbounds)
#    1990         counties = [coords for coords in self.counties]
#    1991         counties = PolyCollection(counties)
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\mpl_toolkits\basemap\__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2154         info = (shf.numRecords,shptype,bbox[0:2]+[0.,0.],bbox[2:]+[0.,0.])
#    2155         npoly = 0
# -> 2156         for shprec in shf.shapeRecords():
#    2157             shp = shprec.shape; rec = shprec.record
#    2158             npoly = npoly + 1
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\shapefile.py in shapeRecords(self)
#    1330         """Returns a list of combination geometry/attribute records for
#    1331         all records in a shapefile."""
# -> 1332         return ShapeRecords(self.iterShapeRecords())
#    1333
#    1334     def iterShapeRecords(self):
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\shapefile.py in iterShapeRecords(self)
#    1335         """Returns a generator of combination geometry/attribute records for
#    1336         all records in a shapefile."""
# -> 1337         for shape, record in izip(self.iterShapes(), self.iterRecords()):
#    1338             yield ShapeRecord(shape=shape, record=record)
#    1339
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\shapefile.py in iterRecords(self)
#    1317         f.seek(self.__dbfHdrLength)
#    1318         for i in xrange(self.numRecords):
# -> 1319             r = self.__record()
#    1320             if r:
#    1321                 yield r
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\shapefile.py in __record(self, oid)
#    1279             else:
#    1280                 # anything else is forced to string/unicode
# -> 1281                 value = u(value, self.encoding, self.encodingErrors)
#    1282                 value = value.strip()
#    1283             record.append(value)
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\shapefile.py in u(v, encoding, encodingErrors)
#     102         if isinstance(v, bytes):
#     103             # For python 3 decode bytes to str.
# --> 104             return v.decode(encoding, encodingErrors)
#     105         elif isinstance(v, str):
#     106             # Already str.
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte
